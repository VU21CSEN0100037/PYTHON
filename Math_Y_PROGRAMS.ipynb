# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100037/PYTHON/blob/main/Math_Y_PROGRAMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([12, 80])
ypoints = np.array([22, 100])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
exam = np.array(["phys", "maths", "Clad", "development","IT","ENG"])
marks= np.array([80, 60,55, 70,90,43])
plt.bar(exam,marks)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

m = np.array([55,65,75,85])
a=["eng","phys","maths","IT"]

plt.pie(m,labels=a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(70, 50, 100)

plt.hist(x)
plt.show()
